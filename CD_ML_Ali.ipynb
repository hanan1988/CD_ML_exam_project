# %% [markdown]
# <a href="https://colab.research.google.com/github/hanan1988/HANAN_ALI_CD_ML_exam_project/blob/main/CD_ML_Ali.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Circular dichroism (CD) is a spectroscopic technique used to study the optical properties of chiral molecules. Chiral molecules are those that are not superimposable on their mirror image, meaning they exist in two different forms called enantiomers. CD spectroscopy provides information about the structural and electronic properties of chiral molecules by measuring the difference in absorption of left-handed circularly polarized light (LCP) and right-handed circularly polarized light (RCP).
# The CD spectrum is obtained by measuring the differential absorption of LCP and RCP light as a function of the wavelength and it is defined by:
# \begin{equation} CD(λ) = \frac{A_{lcp}- A_{rcp}}{A_{lcp}+A_{rcp}}\end{equation}
# Where $A_{\rm lcp}$ and $A_{\rm rcp}$ are the absorption of left and right circular polarized light.
#
# The resulting spectrum displays positive and negative bands that correspond to electronic transitions in the molecule. The intensity and shape of these bands can provide insights into the conformation, chirality, secondary structure (e.g., protein folding), and interactions of the molecule under investigation.
#
# In this notebook, we applied DNN to reproduce CD signal of Fig.6 of our recent published results in Optics Express (https://doi.org/10.1364/OE.485324).
#
# In the figure below, we show a simple sketch of the metasurface with tilted elliptic nanohole used to produce the CD signal. A metal layer of thickness (h) is embedded between glass substrate (SiO2) and air. $R_{\rm1}$ ($D_{\rm1}$/2), $R_{\rm2}$ ($D_{\rm2}$/2) are the radii of the nano ellipse. In our published paper we studied the CD signal as a function of the nano ellipse radius $R_{\rm1}$, where we kept $R_{\rm2}$ fixed. In this notebook we tried to reproduce this result which is shown in the map below.
#
# In our case, we have a dataset with two featuers which are the radius $R_{\rm1}$ and wavelength (λ), and the target is CD signal.
#
# In the following I show how I applied NN on our simulation dataset. It is worth mentioning that our problem is a regression problem.
# ![cd.png](data:image/png;base64,...)

# %%
#Step 1: Import related libraries

import numpy as np
import matplotlib.pyplot as plt
import re
import tensorflow as tf
import matplotlib.colors as mcolors
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
import time
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error

# %%
#Step 2 : Mount google drive and load the dataset file
from google.colab import drive
drive.mount('/content/drive')

dataset = '/content/drive/MyDrive/fdtd_cd_map_r1_tilted.txt'  
print(dataset)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/fdtd_cd_map_r1_tilted.txt

# %% [markdown]
# Our dataset file is made of blocks separated by an empty line because we want a map of circular dichroism as a function of the short radius of the nano ellipse, as we see from the map, CD signal increases with increased R1.

# %%
#Step 3: Read the data file: if you do not mind I had to use this function in order to read the dataset file

def read_myfile(f):
    """ reads all columns from a data file made of blocks separated by blank lines"""

    print('entering read_myfile, f=', f)
    x, x_array = [], []    # x is the temporary list that contains each block, x_array is the full list of all blocks

    icount=0
    for line in f:
        line=re.sub("^\s+","",line).rstrip()
        values = [s for s in line.split()]
        if line != '':        # starts reading a block if the line is not empty
            if values[0] != "#" and values[0] != "lambda" and values[0] != "nm": # if we are not in the header...
                ncol = np.shape(values)[0]     # ... we read the number of columns...
                row = []                       # ... and put the line in the list "row"
                for j in range(ncol):
                    row.append(float(values[j]))
                x.append(row)

        else:      #empty line separating different blocks
            #if (icount >= 0): print('read data for icount, x[1]=',icount,x[2][0])
            icount=icount+1
            if ncol != 0:
                x_array.append(x)  # save temporary list in final list

                x = []         # re-initialize temporary list

    x_array=np.asarray(x_array)   # this array has shape (n1, n2) where n1 is the number of rows in each block and n2 is the number of columns
    print('shape(x_array)=',np.shape(x_array))
    print('exiting read_myfile')

    return x_array, ncol

# %%
#Step 4: In this step I wanted to plot the figure showed previously after reading the file

def plot_map(Lambda, R1, A_cd, vmin, vmax, xlabel, ylabel, xticks, yticks, cmap='bwr'):

  ticksfontsize = 10
  labelfontsize = 10
  colorbarfontsize = 10
  titlefontsize = 8
  location='right'

  aspect = (xmax-xmin)/(ymax-ymin)
  extent = xmin, xmax, ymin, ymax
  print('extent=',extent)

  fig = plt.figure(figsize=(4,4), constrained_layout=False)
  ax0 = fig.add_subplot(111)

  ##plot cd as a function of radius (R1) ##
  ax0.set_title('CD map as a function of R1, without interpolation', size = titlefontsize )
  f0=ax0.imshow(A_cd, origin="lower", extent=extent, vmin=vmin, vmax=vmax, cmap=cmap, interpolation = None)
  ax0.set_aspect(aspect)
  ax0.set_xlim([xmin, xmax])
  ax0.set_xticks(xticks)
  ax0.set_xlabel(xlabel, fontsize=labelfontsize)
  ax0.set_ylim([ymin, ymax])
  ax0.set_ylabel(ylabel, fontsize=labelfontsize)
  ax0.set_yticks(yticks)
  ax0.tick_params(labelcolor='black', labelsize=ticksfontsize)
  ax0.xaxis.set_minor_locator(MultipleLocator(100)) 
  ax0.yaxis.set_minor_locator(MultipleLocator(10))  
  cb=fig.colorbar(f0, ax=ax0, shrink=0.6, aspect=15, location=location)
  cb.set_label(label=label, size=colorbarfontsize)
  cb.set_ticks(ticks=np.linspace(vmin, vmax, 3))
  cb.ax.tick_params(labelsize=ticksfontsize)
  ##End ##
filename = 'fdtd_cd_map_r1_tilted.txt'
f = open(dataset,'r')    # file to read the data
x, ncol = read_myfile(f)
f.close()
print("shape of x=", np.shape(x))
nr1, nlambda = np.shape(x)[0], np.shape(x)[1]
print('nr1, nlambda=', nr1, nlambda)
Lambda, R1, A_cd  = x[0,:,0], x[:,0,1], x[:,:,10]
print("shape of Lambda=", np.shape(Lambda))
print("shape of cd=", np.shape(A_cd))

xmin, xmax = Lambda[0], Lambda[-1]
ymin, ymax = R1[0], R1[-1]
nx, ny = 4, 6
xticks  = np.linspace(xmin, xmax, nx)
yticks  = np.linspace(ymin, ymax, ny)
vmin, vmax, label = -0.5, 0.5, r'$CD_{A}$'
xlabel, ylabel = r'Wavelength (nm)', '$R_{1}$ (nm)'
plot_map(Lambda, R1, A_cd, vmin, vmax, xlabel, ylabel, xticks, yticks, cmap='bwr')
# Out:
# entering read_myfile, f= <_io.TextIOWrapper name='/content/drive/MyDrive/fdtd_cd_map_r1_tilted.txt' mode='r' encoding='UTF-8'>
# shape(x_array)= (16, 301, 17)
# exiting read_myfile
# shape of x= (16, 301, 17)
# nr1, nlambda= 16 301
# shape of Lambda= (301,)
# shape of cd= (16, 301)
# extent= (400.0, 1000.0, 100.0, 250.0)

# %%
#Step 5: Define features and target 

ndata = nr1 * nlambda
print(ndata)

CD = np.zeros([ndata])
combined_array = np.zeros([ndata, 2])

ind = 0
for j1 in range(nr1):
  for j2 in range(nlambda):

    combined_array[ind, 0] = R1[j1]
    combined_array[ind, 1] = Lambda[j2]
    
    CD[ind] = A_cd[j1,j2]
    ind = ind+1

target = CD
print("shape of target=", target.shape, target)

features = combined_array
print("shape of features=", features.shape, features)
# Out:
# 4816
# shape of target= (4816,) [ 1.35167e-01  1.24325e-01  1.12679e-01 ... -6.37502e-08 -6.12384e-08
#  -6.01737e-08]
# shape of features= (4816, 2) [[ 100.  400.]
#  [ 100.  402.]
#  [ 100.  404.]
#  ...
#  [ 250.  996.]
#  [ 250.  998.]
#  [ 250. 1000.]]

# %%
#Step 6: Split the dataset into training and testing sets where 
""" I chose 50% of the data to be used for testing, and the remaining 50% will be used for training the model."""

X_train, X_val, y_train, y_val = train_test_split(features, target, test_size=0.5, random_state = 42)
print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
#print("X_train=", X_train)
#print("Y_train=", y_train)
#print("X_val=", X_val)
#print("y_val=", y_val)
# Out:
# (2408, 2) (2408, 2) (2408,) (2408,)

# %%
#Step 7: Normalizing the data 

from sklearn import preprocessing

# fit data
scaler = preprocessing.StandardScaler().fit(X_train)
# scaling data
X_train = scaler.transform(X_train)
X_val = scaler.transform(X_val)

# %%
#Step 8: Building the neural network 
""" The resulting spectrum displays positive and negative bands in the 
    interval [-1 1], I had to use tanh activation function on the output layer 
    but for the hidden layers I used relu activation function."""

input_shape = X_train.shape[1]
#  this list of layer was chosen after I tried many layers with different 
#  number of neurons, and this NN worked for my data 

layer_list = [4,10,32,64,32,10,4,2] 
act = 'relu'
act1 = 'tanh'

model = tf.keras.Sequential()

model.add(tf.keras.layers.Dense(layer_list[0], input_shape=(input_shape,),activation=act))
for layer in layer_list[1:]:
  model.add(tf.keras.layers.Dense(layer,activation=act))
model.add(tf.keras.layers.Dense(1,activation=act1))

# %%
#Step 9: Compile the model

model.compile(loss='mean_squared_error', optimizer= Adam(lr = 1e-3))
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 4)                 12
#
#  dense_1 (Dense)             (None, 10)                50
#
#  dense_2 (Dense)             (None, 32)                352
#
#  dense_3 (Dense)             (None, 64)                2112
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dense_5 (Dense)             (None, 10)                330
#
#  dense_6 (Dense)             (None, 4)                 44
#
#  dense_7 (Dense)             (None, 2)                 10
#
#  dense_8 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 4,993
# Trainable params: 4,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Step 10: Train the model

batch_size = 150
n_epochs = 300  # choose this value for a quick calculation (only main two peaks are reproduced)
#n_epochs = 5000 # choose this value for a precise calculation, but much slower 

history = model.fit(X_train, y_train, epochs = n_epochs, batch_size = batch_size, 
                    verbose=1, validation_data = (X_val, y_val))
# Out:
# Epoch 1/300
# 17/17 [==============================] - 3s 33ms/step - loss: 0.0109 - val_loss: 0.0098
# Epoch 2/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0104 - val_loss: 0.0094
# Epoch 3/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0097 - val_loss: 0.0085
# Epoch 4/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0086 - val_loss: 0.0076
# Epoch 5/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0080 - val_loss: 0.0074
# Epoch 6/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 7/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0073 - val_loss: 0.0067
# Epoch 8/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 9/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0067 - val_loss: 0.0063
# Epoch 10/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 11/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 12/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 13/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0056 - val_loss: 0.0054
# Epoch 14/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 15/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0049 - val_loss: 0.0048
# Epoch 16/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 17/300
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0045 - val_loss: 0.0046
# Epoch 18/300
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 19/300
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 20/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 21/300
# 17/17 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0039
# Epoch 22/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 23/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 24/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 25/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 26/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 27/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 28/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0033 - val_loss: 0.0034
# Epoch 29/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 30/300
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 31/300
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 32/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 33/300
# 17/17 [==============================] - 0s 15ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 34/300
# 17/17 [==============================] - 0s 18ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 35/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 36/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 37/300
# 17/17 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0025
# Epoch 38/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 39/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 40/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 41/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 42/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 43/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 44/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0027
# Epoch 45/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 46/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 47/300
# 17/17 [==============================] - 0s 14ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 48/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 49/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 50/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 51/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 52/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 53/300
# 17/17 [==============================] - 0s 17ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 54/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 55/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 56/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 57/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 0.0024
# Epoch 58/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 59/300
# 17/17 [==============================] - 0s 11ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 60/300
# 17/17 [==============================] - 0s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 61/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 62/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 63/300
# 17/17 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 64/300
# 17/17 [==============================] - 0s 10ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 65/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 66/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0020
# Epoch 67/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 68/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 69/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0019
# Epoch 70/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 71/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 0.0019
# Epoch 72/300
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 73/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 74/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 75/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 76/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0018
# Epoch 77/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 78/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 79/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 80/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0015 - val_loss: 0.0016
# Epoch 81/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 82/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0021 - val_loss: 0.0020
# Epoch 83/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 84/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 85/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 86/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 87/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 88/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 89/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 90/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 91/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 92/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 93/300
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 94/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 95/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 96/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 97/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 98/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0015
# Epoch 99/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 100/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 101/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 102/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0018
# Epoch 103/300
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0017 - val_loss: 0.0028
# Epoch 104/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 0.0015
# Epoch 105/300
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 106/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 107/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 108/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 109/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 110/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 111/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 112/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 113/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0012
# Epoch 114/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 115/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 116/300
# 17/17 [==============================] - 0s 4ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 117/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 118/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 119/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 120/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 121/300
# 17/17 [==============================] - 0s 5ms/step - loss: 9.5107e-04 - val_loss: 0.0010
# Epoch 122/300
# 17/17 [==============================] - 0s 7ms/step - loss: 9.6151e-04 - val_loss: 9.7002e-04
# Epoch 123/300
# 17/17 [==============================] - 0s 9ms/step - loss: 9.4103e-04 - val_loss: 9.1184e-04
# Epoch 124/300
# 17/17 [==============================] - 0s 8ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 125/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 126/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 127/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 128/300
# 17/17 [==============================] - 0s 10ms/step - loss: 9.1557e-04 - val_loss: 0.0011
# Epoch 129/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 130/300
# 17/17 [==============================] - 0s 9ms/step - loss: 9.4473e-04 - val_loss: 9.5244e-04
# Epoch 131/300
# 17/17 [==============================] - 0s 7ms/step - loss: 9.3393e-04 - val_loss: 8.6101e-04
# Epoch 132/300
# 17/17 [==============================] - 0s 7ms/step - loss: 8.9924e-04 - val_loss: 0.0011
# Epoch 133/300
# 17/17 [==============================] - 0s 7ms/step - loss: 9.1063e-04 - val_loss: 8.2944e-04
# Epoch 134/300
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2264e-04 - val_loss: 0.0011
# Epoch 135/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 136/300
# 17/17 [==============================] - 0s 7ms/step - loss: 9.2373e-04 - val_loss: 8.4995e-04
# Epoch 137/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 9.7687e-04
# Epoch 138/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 0.0013
# Epoch 139/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 140/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 141/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 142/300
# 17/17 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 8.7338e-04
# Epoch 143/300
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4528e-04 - val_loss: 8.0144e-04
# Epoch 144/300
# 17/17 [==============================] - 0s 10ms/step - loss: 8.5943e-04 - val_loss: 7.7152e-04
# Epoch 145/300
# 17/17 [==============================] - 0s 7ms/step - loss: 8.2021e-04 - val_loss: 8.5126e-04
# Epoch 146/300
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4119e-04 - val_loss: 8.1883e-04
# Epoch 147/300
# 17/17 [==============================] - 0s 9ms/step - loss: 8.7604e-04 - val_loss: 8.0837e-04
# Epoch 148/300
# 17/17 [==============================] - 0s 7ms/step - loss: 8.4356e-04 - val_loss: 7.4000e-04
# Epoch 149/300
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7380e-04 - val_loss: 7.5120e-04
# Epoch 150/300
# 17/17 [==============================] - 0s 6ms/step - loss: 7.5589e-04 - val_loss: 8.2247e-04
# Epoch 151/300
# 17/17 [==============================] - 0s 8ms/step - loss: 7.9852e-04 - val_loss: 7.5874e-04
# Epoch 152/300
# 17/17 [==============================] - 0s 7ms/step - loss: 7.2961e-04 - val_loss: 7.7631e-04
# Epoch 153/300
# 17/17 [==============================] - 0s 9ms/step - loss: 7.3214e-04 - val_loss: 0.0012
# Epoch 154/300
# 17/17 [==============================] - 0s 7ms/step - loss: 9.8672e-04 - val_loss: 7.6910e-04
# Epoch 155/300
# 17/17 [==============================] - 0s 9ms/step - loss: 7.4958e-04 - val_loss: 7.5086e-04
# Epoch 156/300
# 17/17 [==============================] - 0s 7ms/step - loss: 7.1346e-04 - val_loss: 8.0448e-04
# Epoch 157/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.6827e-04 - val_loss: 7.6785e-04
# Epoch 158/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.1601e-04 - val_loss: 7.6370e-04
# Epoch 159/300
# 17/17 [==============================] - 0s 5ms/step - loss: 9.5268e-04 - val_loss: 9.6817e-04
# Epoch 160/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.2825e-04 - val_loss: 6.6170e-04
# Epoch 161/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.6911e-04 - val_loss: 7.8194e-04
# Epoch 162/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.0213e-04 - val_loss: 7.1457e-04
# Epoch 163/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.5609e-04 - val_loss: 6.3207e-04
# Epoch 164/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.5357e-04 - val_loss: 7.6735e-04
# Epoch 165/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.9109e-04 - val_loss: 7.0642e-04
# Epoch 166/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.7462e-04 - val_loss: 6.3188e-04
# Epoch 167/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.5270e-04 - val_loss: 6.9654e-04
# Epoch 168/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.4350e-04 - val_loss: 6.5474e-04
# Epoch 169/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.4934e-04 - val_loss: 9.5048e-04
# Epoch 170/300
# 17/17 [==============================] - 0s 5ms/step - loss: 9.3767e-04 - val_loss: 9.1845e-04
# Epoch 171/300
# 17/17 [==============================] - 0s 4ms/step - loss: 8.4466e-04 - val_loss: 0.0012
# Epoch 172/300
# 17/17 [==============================] - 0s 5ms/step - loss: 8.6568e-04 - val_loss: 7.0425e-04
# Epoch 173/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.8574e-04 - val_loss: 7.2890e-04
# Epoch 174/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.2535e-04 - val_loss: 9.3017e-04
# Epoch 175/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.2729e-04 - val_loss: 6.2116e-04
# Epoch 176/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.7364e-04 - val_loss: 5.9636e-04
# Epoch 177/300
# 17/17 [==============================] - 0s 5ms/step - loss: 8.4817e-04 - val_loss: 7.4688e-04
# Epoch 178/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.7844e-04 - val_loss: 8.6154e-04
# Epoch 179/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.6494e-04 - val_loss: 6.9794e-04
# Epoch 180/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.8291e-04 - val_loss: 6.5231e-04
# Epoch 181/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.9646e-04 - val_loss: 6.3177e-04
# Epoch 182/300
# 17/17 [==============================] - 0s 7ms/step - loss: 5.8563e-04 - val_loss: 6.6387e-04
# Epoch 183/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.3807e-04 - val_loss: 7.3149e-04
# Epoch 184/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.2704e-04 - val_loss: 6.2609e-04
# Epoch 185/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.7965e-04 - val_loss: 6.2055e-04
# Epoch 186/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.8023e-04 - val_loss: 6.5786e-04
# Epoch 187/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.8656e-04 - val_loss: 7.9818e-04
# Epoch 188/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.5714e-04 - val_loss: 7.3306e-04
# Epoch 189/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.1388e-04 - val_loss: 8.7820e-04
# Epoch 190/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.9900e-04 - val_loss: 5.5339e-04
# Epoch 191/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.7354e-04 - val_loss: 6.0849e-04
# Epoch 192/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.5079e-04 - val_loss: 6.0674e-04
# Epoch 193/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.6856e-04 - val_loss: 6.2169e-04
# Epoch 194/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.7316e-04 - val_loss: 5.4266e-04
# Epoch 195/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.5559e-04 - val_loss: 5.6757e-04
# Epoch 196/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.2898e-04 - val_loss: 5.3101e-04
# Epoch 197/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.5395e-04 - val_loss: 7.8494e-04
# Epoch 198/300
# 17/17 [==============================] - 0s 7ms/step - loss: 7.4305e-04 - val_loss: 6.6929e-04
# Epoch 199/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.6170e-04 - val_loss: 7.4232e-04
# Epoch 200/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.3759e-04 - val_loss: 5.6385e-04
# Epoch 201/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.5680e-04 - val_loss: 6.3783e-04
# Epoch 202/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.9854e-04 - val_loss: 5.5740e-04
# Epoch 203/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.3233e-04 - val_loss: 5.5274e-04
# Epoch 204/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.0219e-04 - val_loss: 5.2884e-04
# Epoch 205/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.8639e-04 - val_loss: 6.2882e-04
# Epoch 206/300
# 17/17 [==============================] - 0s 8ms/step - loss: 5.1719e-04 - val_loss: 6.0956e-04
# Epoch 207/300
# 17/17 [==============================] - 0s 7ms/step - loss: 5.9723e-04 - val_loss: 6.3830e-04
# Epoch 208/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.2818e-04 - val_loss: 6.9856e-04
# Epoch 209/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.1017e-04 - val_loss: 5.2568e-04
# Epoch 210/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.1999e-04 - val_loss: 5.2070e-04
# Epoch 211/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.0712e-04 - val_loss: 7.1638e-04
# Epoch 212/300
# 17/17 [==============================] - 0s 5ms/step - loss: 8.7000e-04 - val_loss: 7.2148e-04
# Epoch 213/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.4537e-04 - val_loss: 8.0203e-04
# Epoch 214/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.6196e-04 - val_loss: 6.1422e-04
# Epoch 215/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.6332e-04 - val_loss: 5.9494e-04
# Epoch 216/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.8858e-04 - val_loss: 4.8400e-04
# Epoch 217/300
# 17/17 [==============================] - 0s 7ms/step - loss: 5.5984e-04 - val_loss: 5.1634e-04
# Epoch 218/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.8782e-04 - val_loss: 4.6499e-04
# Epoch 219/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.5908e-04 - val_loss: 5.4929e-04
# Epoch 220/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.7739e-04 - val_loss: 5.5770e-04
# Epoch 221/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.7149e-04 - val_loss: 7.2181e-04
# Epoch 222/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0011 - val_loss: 0.0031
# Epoch 223/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 0.0018
# Epoch 224/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 225/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 9.1484e-04
# Epoch 226/300
# 17/17 [==============================] - 0s 5ms/step - loss: 8.2718e-04 - val_loss: 0.0010
# Epoch 227/300
# 17/17 [==============================] - 0s 5ms/step - loss: 9.9664e-04 - val_loss: 7.5024e-04
# Epoch 228/300
# 17/17 [==============================] - 0s 5ms/step - loss: 8.3600e-04 - val_loss: 7.1475e-04
# Epoch 229/300
# 17/17 [==============================] - 0s 5ms/step - loss: 7.2393e-04 - val_loss: 8.6185e-04
# Epoch 230/300
# 17/17 [==============================] - 0s 7ms/step - loss: 7.5567e-04 - val_loss: 6.9352e-04
# Epoch 231/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.5371e-04 - val_loss: 7.0181e-04
# Epoch 232/300
# 17/17 [==============================] - 0s 7ms/step - loss: 7.7734e-04 - val_loss: 5.9317e-04
# Epoch 233/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.7280e-04 - val_loss: 8.8683e-04
# Epoch 234/300
# 17/17 [==============================] - 0s 5ms/step - loss: 0.0012 - val_loss: 7.4198e-04
# Epoch 235/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.6090e-04 - val_loss: 5.5067e-04
# Epoch 236/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.5471e-04 - val_loss: 5.5275e-04
# Epoch 237/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.9023e-04 - val_loss: 5.9017e-04
# Epoch 238/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.1065e-04 - val_loss: 5.8869e-04
# Epoch 239/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.6761e-04 - val_loss: 7.4772e-04
# Epoch 240/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.0131e-04 - val_loss: 5.2812e-04
# Epoch 241/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.0426e-04 - val_loss: 5.1582e-04
# Epoch 242/300
# 17/17 [==============================] - 0s 7ms/step - loss: 4.8675e-04 - val_loss: 4.9581e-04
# Epoch 243/300
# 17/17 [==============================] - 0s 7ms/step - loss: 5.0969e-04 - val_loss: 5.2290e-04
# Epoch 244/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.6620e-04 - val_loss: 5.5777e-04
# Epoch 245/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.8024e-04 - val_loss: 5.3760e-04
# Epoch 246/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.7491e-04 - val_loss: 4.9791e-04
# Epoch 247/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.8192e-04 - val_loss: 4.6642e-04
# Epoch 248/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.0723e-04 - val_loss: 4.5213e-04
# Epoch 249/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.6428e-04 - val_loss: 5.0398e-04
# Epoch 250/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.9598e-04 - val_loss: 4.5867e-04
# Epoch 251/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.0234e-04 - val_loss: 5.0855e-04
# Epoch 252/300
# 17/17 [==============================] - 0s 7ms/step - loss: 4.6217e-04 - val_loss: 5.1776e-04
# Epoch 253/300
# 17/17 [==============================] - 0s 8ms/step - loss: 4.4098e-04 - val_loss: 5.6306e-04
# Epoch 254/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.1743e-04 - val_loss: 5.0067e-04
# Epoch 255/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.6736e-04 - val_loss: 5.5621e-04
# Epoch 256/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.4333e-04 - val_loss: 4.6864e-04
# Epoch 257/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.2318e-04 - val_loss: 5.4493e-04
# Epoch 258/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.2307e-04 - val_loss: 5.4714e-04
# Epoch 259/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.2673e-04 - val_loss: 5.6249e-04
# Epoch 260/300
# 17/17 [==============================] - 0s 8ms/step - loss: 4.6655e-04 - val_loss: 4.9747e-04
# Epoch 261/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.6128e-04 - val_loss: 4.8503e-04
# Epoch 262/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.0766e-04 - val_loss: 4.3863e-04
# Epoch 263/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.5934e-04 - val_loss: 4.9669e-04
# Epoch 264/300
# 17/17 [==============================] - 0s 5ms/step - loss: 4.3259e-04 - val_loss: 5.2423e-04
# Epoch 265/300
# 17/17 [==============================] - 0s 8ms/step - loss: 4.0942e-04 - val_loss: 6.3444e-04
# Epoch 266/300
# 17/17 [==============================] - 0s 10ms/step - loss: 4.8777e-04 - val_loss: 5.6734e-04
# Epoch 267/300
# 17/17 [==============================] - 0s 7ms/step - loss: 4.9795e-04 - val_loss: 8.8742e-04
# Epoch 268/300
# 17/17 [==============================] - 0s 9ms/step - loss: 7.0182e-04 - val_loss: 7.0643e-04
# Epoch 269/300
# 17/17 [==============================] - 0s 7ms/step - loss: 6.4520e-04 - val_loss: 5.5990e-04
# Epoch 270/300
# 17/17 [==============================] - 0s 9ms/step - loss: 4.7884e-04 - val_loss: 4.3650e-04
# Epoch 271/300
# 17/17 [==============================] - 0s 8ms/step - loss: 4.1468e-04 - val_loss: 4.9534e-04
# Epoch 272/300
# 17/17 [==============================] - 0s 10ms/step - loss: 3.8349e-04 - val_loss: 4.3961e-04
# Epoch 273/300
# 17/17 [==============================] - 0s 9ms/step - loss: 3.7529e-04 - val_loss: 4.7038e-04
# Epoch 274/300
# 17/17 [==============================] - 0s 10ms/step - loss: 4.6354e-04 - val_loss: 4.2047e-04
# Epoch 275/300
# 17/17 [==============================] - 0s 8ms/step - loss: 3.6973e-04 - val_loss: 4.2482e-04
# Epoch 276/300
# 17/17 [==============================] - 0s 9ms/step - loss: 3.7980e-04 - val_loss: 4.1130e-04
# Epoch 277/300
# 17/17 [==============================] - 0s 8ms/step - loss: 3.9710e-04 - val_loss: 4.0822e-04
# Epoch 278/300
# 17/17 [==============================] - 0s 8ms/step - loss: 4.3055e-04 - val_loss: 9.8685e-04
# Epoch 279/300
# 17/17 [==============================] - 0s 9ms/step - loss: 0.0018 - val_loss: 6.4602e-04
# Epoch 280/300
# 17/17 [==============================] - 0s 7ms/step - loss: 7.8795e-04 - val_loss: 8.0498e-04
# Epoch 281/300
# 17/17 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 7.6324e-04
# Epoch 282/300
# 17/17 [==============================] - 0s 6ms/step - loss: 6.3988e-04 - val_loss: 5.4266e-04
# Epoch 283/300
# 17/17 [==============================] - 0s 7ms/step - loss: 4.3948e-04 - val_loss: 5.1314e-04
# Epoch 284/300
# 17/17 [==============================] - 0s 7ms/step - loss: 5.0548e-04 - val_loss: 4.8442e-04
# Epoch 285/300
# 17/17 [==============================] - 0s 7ms/step - loss: 4.0581e-04 - val_loss: 4.0519e-04
# Epoch 286/300
# 17/17 [==============================] - 0s 9ms/step - loss: 3.7126e-04 - val_loss: 3.9769e-04
# Epoch 287/300
# 17/17 [==============================] - 0s 7ms/step - loss: 4.0855e-04 - val_loss: 5.8230e-04
# Epoch 288/300
# 17/17 [==============================] - 0s 9ms/step - loss: 8.1324e-04 - val_loss: 5.8805e-04
# Epoch 289/300
# 17/17 [==============================] - 0s 9ms/step - loss: 5.6725e-04 - val_loss: 5.4152e-04
# Epoch 290/300
# 17/17 [==============================] - 0s 7ms/step - loss: 5.0482e-04 - val_loss: 4.8094e-04
# Epoch 291/300
# 17/17 [==============================] - 0s 6ms/step - loss: 4.6005e-04 - val_loss: 4.9377e-04
# Epoch 292/300
# 17/17 [==============================] - 0s 7ms/step - loss: 4.4537e-04 - val_loss: 4.3620e-04
# Epoch 293/300
# 17/17 [==============================] - 0s 9ms/step - loss: 4.0317e-04 - val_loss: 6.1329e-04
# Epoch 294/300
# 17/17 [==============================] - 0s 7ms/step - loss: 4.0461e-04 - val_loss: 4.5188e-04
# Epoch 295/300
# 17/17 [==============================] - 0s 9ms/step - loss: 3.6755e-04 - val_loss: 4.7498e-04
# Epoch 296/300
# 17/17 [==============================] - 0s 7ms/step - loss: 4.1775e-04 - val_loss: 3.9894e-04
# Epoch 297/300
# 17/17 [==============================] - 0s 6ms/step - loss: 3.8101e-04 - val_loss: 5.4442e-04
# Epoch 298/300
# 17/17 [==============================] - 0s 5ms/step - loss: 6.1661e-04 - val_loss: 0.0010
# Epoch 299/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.8432e-04 - val_loss: 7.4729e-04
# Epoch 300/300
# 17/17 [==============================] - 0s 5ms/step - loss: 5.6423e-04 - val_loss: 6.8569e-04

# %%
#Step 11:  plot training history
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.yscale('log')
plt.title('Training History')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['training', 'validation'], loc='upper right')
plt.show()

# %%
#Step 12: Evaluate the model
#☻ prediction on the validation set
y_pred = model.predict(scaler.transform(X_val)) # predicted values CD after the training
#print(y_pred)

# Calculate the root mean squared deviation (RMSD)
mse = mean_squared_error(y_val, y_pred)
n_val = y_val.shape[0]
print("n_val=", n_val)

rmsd = np.sqrt(mse)

for j in range (n_val):

  if ((j//100)*100 == j): print(X_val[j,0],X_val[j,1], y_val[j], y_pred[j][0], \
       y_val[j]-y_pred[j][0])

print("Average=", np.sum(y_val)/len(y_val))
print("Mean Squared Error:", mse)
print('Root Mean Squared Deviation:', rmsd)

print("shape of y_pred=", y_pred.shape)
print("X_val, y_val =", X_val.shape, y_val.shape)
# Out:
# 76/76 [==============================] - 0s 1ms/step
# n_val= 2408
# -0.3415684688309136 0.41960624220795445 -0.266908 0.69687814 -0.9637861352043151
# 0.971625048377452 -0.13380401246883158 0.0514727 0.6962649 -0.6447922226188659
# -0.5604340550323078 -0.7563905489802158 0.0439626 0.697668 -0.6537054159568787
# -1.6547619860392793 -1.2290951415166371 -0.091576 0.69868207 -0.7902580697784424
# 0.7527594621760578 1.6763086955364894 0.0604574 0.6954321 -0.6349747265220642
# 0.971625048377452 -1.1829776202935718 -0.031815 0.69683516 -0.7286501602554322
# -0.9981652274350964 0.869252074132843 0.0487172 0.69709074 -0.648373544972229
# -0.9981652274350964 -0.6756848868398512 -0.0346066 0.69792783 -0.7325344326034546
# 1.6282218069816348 0.40807686190218806 1.90945e-08 0.69551224 -0.6955122160701424
# 1.1904906345788464 0.25819491792722515 -0.0455254 0.69589925 -0.741424648123169
# -0.9981652274350964 -1.067683817235908 -0.388914 0.6981401 -1.0870540847434997
# -1.4358963998378849 -1.0446250566243753 -0.33676 0.69843084 -1.035190836200714
# -0.5604340550323078 1.019134018107806 0.0732611 0.6967049 -0.6234438241065979
# -0.9981652274350964 0.5118412846540854 -0.0634802 0.69728464 -0.7607648388816833
# 0.09616270357187497 0.4657237634310199 -0.189512 0.6965487 -0.8860607003326416
# -1.2170308136364907 0.3850181012906553 -0.159405 0.6975054 -0.8569104144859314
# -0.5604340550323078 1.5379561318672927 0.08737 0.6964232 -0.6090531729507447
# 1.4093562207802406 -0.9523900141782442 -0.0673078 0.6964052 -0.7637129723480225
# -0.3415684688309136 -1.2290951415166371 -0.0269729 0.69777226 -0.7247451644805908
# 0.7527594621760578 1.699367456148022 0.0603887 0.69541967 -0.6350309691513062
# 0.5338938759746635 -0.06462773063423333 0.0959268 0.69653213 -0.6006053302413941
# -0.9981652274350964 -1.010036915707076 -0.423601 0.69810903 -1.121710030723572
# 0.09616270357187497 -0.03003958971693421 0.0873073 0.696818 -0.6095106941177368
# -0.9981652274350964 0.16595987548109417 0.070955 0.69747216 -0.6265171550941467
# 1.4093562207802406 -1.5058002688550303 -0.0144318 0.69670594 -0.7111377373855591
# Average= -0.00450647493178163
# Mean Squared Error: 0.5027151265847627
# Root Mean Squared Deviation: 0.7090240662944824
# shape of y_pred= (2408, 1)
# X_val, y_val = (2408, 2) (2408,)

# %%
# prediction on a full rectangular grid, in order to compare with the original plot

# definition of the array of shape (nr1*nlambda,2) 
r1_lambda_array = []
index = 0
for j1 in range(nr1):
  for j2 in range(nlambda):
    r1_lambda_array.append([R1[j1], Lambda[j2]])
    index = index+1 
print(np.shape(r1_lambda_array))

# predict values on the full grid
y_pred_array = model.predict(scaler.transform(r1_lambda_array))

# define a grid of shape (nr1, nlambda) for plotting
y_pred_grid = np.zeros([nr1,nlambda])
index = 0
for j1 in range(nr1):
  for j2 in range(nlambda):
    y_pred_grid[j1,j2] = y_pred_array[index]
    index = index+1
    
# let us plot the results
r1min, r1max, lambdamin, lambdamax = R1[0], R1[-1], Lambda[0], Lambda[-1]
extent = lambdamin, lambdamax, r1min, r1max
aspect = (lambdamax-lambdamin)/(r1max-r1min)
print('extent=',extent)
cmap = 'bwr'
vmin, vmax = -0.5, 0.5
nx, ny = 4, 6
xticks  = np.linspace(lambdamin, lambdamax, nx)
yticks  = np.linspace(r1min, r1max, ny)

print("shape of A_cd:","shape of pred_cd:", np.shape(A_cd), np.shape(y_pred_grid))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(6,5), sharey=True)
plt.subplots_adjust(wspace= 0.5)
ax1.set_title("Original data", size = 10)
f0 = ax1.imshow(A_cd, extent=extent, vmin=vmin, vmax=vmax, origin="lower", cmap=cmap, interpolation = None)
ax1.set_aspect(aspect)
ax1.set_xlabel('Wavelength (nm)')
ax1.set_xlim(Lambda[0], Lambda[-1])
ax1.set_xticks(xticks)
ax1.set_ylabel('R1 (nm)')
ax1.set_ylim(R1[0], R1[-1])
ax1.set_yticks(yticks)
ax1.xaxis.set_minor_locator(MultipleLocator(100)) 
ax1.yaxis.set_minor_locator(MultipleLocator(10))  

ax2.set_title("pred_CD on the same original grid", size = 10)
f0 = ax2.imshow(y_pred_grid, extent=extent, vmin=vmin, vmax=vmax, origin="lower", cmap=cmap)
ax2.set_aspect(aspect)
ax2.set_xlabel('Wavelength (nm)')
ax2.set_xlim(Lambda[0], Lambda[-1])
ax2.set_xticks(xticks)
ax2.xaxis.set_minor_locator(MultipleLocator(100)) 
ax2.yaxis.set_minor_locator(MultipleLocator(10))  

cb   = fig.add_axes([0.95, 0.35, 0.025, 0.3])
cbar = fig.colorbar(f0, cb)
cbar.set_label('CD', size=12)
cbar.set_ticks(ticks=np.linspace(vmin, vmax, 3))
# Out:
# (4816, 2)
# 151/151 [==============================] - 0s 1ms/step
# extent= (400.0, 1000.0, 100.0, 250.0)
# shape of A_cd: shape of pred_cd: (16, 301) (16, 301)

# %% [markdown]
# In this part we want to use the NN to predict new results of CD on a dense grid. Since the original calculations done in FDTD are time consuming, we can use instead the NN.
# We can see that the NN is working as an interpolation technique.

# %%
# prediction on a full rectangular grid that is twice as dense

# definition of new numbers of points
nrr1 = 2*nr1-1
nllambda = 2*nlambda-1

# definition of new arrays that are twice as dense
RR1 = np.linspace(R1[0], R1[-1], nrr1)
#print(RR1)
LLambda = np.linspace(Lambda[0], Lambda[-1], nllambda)
#print(LLambda)

# definition of the array of shape (nrr1*nllambda, 2) 
rr1_llambda_array = []
index = 0
for j1 in range(nrr1):
  for j2 in range(nllambda):
    rr1_llambda_array.append([RR1[j1], LLambda[j2]])
    index = index+1 
print(np.shape(rr1_llambda_array))

# predict values on the full grid
yy_pred_array = model.predict(scaler.transform(rr1_llambda_array))

# define a grid of shape (nnr1, nnlambda) for plotting
yy_pred_grid = np.zeros([nrr1,nllambda])
index = 0
for j1 in range(nrr1):
  for j2 in range(nllambda):
    yy_pred_grid[j1,j2] = yy_pred_array[index]
    index = index+1
    
# let us plot the results
r1min, r1max, lambdamin, lambdamax = R1[0], R1[-1], Lambda[0], Lambda[-1]
extent = lambdamin, lambdamax, r1min, r1max
aspect = (lambdamax-lambdamin)/(r1max-r1min)
print('extent=',extent)
cmap = 'bwr'
vmin, vmax = -0.5, 0.5

print("shape of A_cd:","shape of pred_cd:", np.shape(A_cd), np.shape(yy_pred_grid))

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10,5), sharey=True)
plt.subplots_adjust(wspace= 0.5)
ax1.set_title("Original data without interpolation", size = 10)
f0 = ax1.imshow(A_cd, extent=extent, vmin=vmin, vmax=vmax, origin="lower", cmap=cmap)
ax1.set_aspect(aspect)
ax1.set_xlabel('Wavelength (nm)')
ax1.set_xlim(Lambda[0], Lambda[-1])
ax1.set_xticks(xticks)
ax1.set_ylabel('R1 (nm)')
ax1.set_ylim(R1[0], R1[-1])
ax1.set_yticks(yticks)
ax1.xaxis.set_minor_locator(MultipleLocator(100)) 
ax1.yaxis.set_minor_locator(MultipleLocator(10))  

ax2.set_title("pred_CD on the same original grid", size = 10)
f0 = ax2.imshow(y_pred_grid, extent=extent, vmin=vmin, vmax=vmax, origin="lower", cmap=cmap, interpolation = None)
ax2.set_aspect(aspect)
ax2.set_xlabel('Wavelength (nm)')
ax2.set_xlim(Lambda[0], Lambda[-1])
ax2.set_xticks(xticks)
ax2.set_ylim(R1[0], R1[-1])
ax2.set_yticks(yticks)
ax2.xaxis.set_minor_locator(MultipleLocator(100)) 
ax2.yaxis.set_minor_locator(MultipleLocator(10))  

ax3.set_title("pred_CD on grid that is twice as dense", size = 10)
f0 = ax3.imshow(yy_pred_grid, extent=extent, vmin=vmin, vmax=vmax, origin="lower", cmap=cmap)
ax3.set_aspect(aspect)
ax3.set_xlabel('Wavelength (nm)')
ax3.set_xlim(Lambda[0], Lambda[-1])
ax3.set_xticks(xticks)
ax3.set_ylim(R1[0], R1[-1])
ax3.set_yticks(yticks)
ax3.xaxis.set_minor_locator(MultipleLocator(100)) 
ax3.yaxis.set_minor_locator(MultipleLocator(10))  

cb   = fig.add_axes([0.95, 0.35, 0.015, 0.3])
cbar = fig.colorbar(f0, cb)
cbar.set_label('CD', size=12)
cbar.set_ticks(ticks=np.linspace(vmin, vmax, 3))
# Out:
# (18631, 2)
# 583/583 [==============================] - 1s 1ms/step
# extent= (400.0, 1000.0, 100.0, 250.0)
# shape of A_cd: shape of pred_cd: (16, 301) (31, 601)
